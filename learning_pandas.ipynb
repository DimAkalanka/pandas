# %% [markdown]
# # **Pandas**

# %% [markdown]
# How to import data and work with data using pandas

# %%
import  pandas as pd

# %% [markdown]
# We should mount google drive beforeuse. If we don't mount our google drive error will show.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
url = '/content/drive/My Drive/Data_for_ML/cars_info.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#          ID                                               Name   Price  \
# 0  11530130                  2010 Toyota Rukus Build 2 AZE151R    9999
# 1  12190570  2021 Mercedes-Benz V 250 D Avantgarde MWB 447 ...  117990
# 2  12321855  2021 Mercedes-Benz Valente 116 CDI MWB RWD 447...   79990
# 3  12346971         2010 Mercedes-Benz E250 CDI Avantgarde 207   34990
# 4  12363884                       2016 Holden Cruze CD JH MY16   15990
#
#            Brand    Model               Variant    Series  Year  Kilometers  \
# 0         Toyota    Rukus               Build 2   AZE151R  2010      263000
# 1  Mercedes-Benz        V  250 D Avantgarde MWB  447 MY21  2021          19
# 2  Mercedes-Benz  Valente       116 CDI MWB RWD  447 MY21  2021          24
# 3  Mercedes-Benz     E250        CDI Avantgarde       207  2010      120579
# 4         Holden    Cruze                    CD   JH MY16  2016       72506
#
#           Type    Gearbox             Fuel         Status    CC  Color  \
# ...

# %% [markdown]
# If we use header = None it will treat first raw also as a dataset ( features)

# %%
df1 = pd.read_csv(url, header = None)
df1.head()
# Out:
#          0                                                  1       2   \
# 0        ID                                               Name   Price
# 1  11530130                  2010 Toyota Rukus Build 2 AZE151R    9999
# 2  12190570  2021 Mercedes-Benz V 250 D Avantgarde MWB 447 ...  117990
# 3  12321855  2021 Mercedes-Benz Valente 116 CDI MWB RWD 447...   79990
# 4  12346971         2010 Mercedes-Benz E250 CDI Avantgarde 207   34990
#
#               3        4                     5         6     7           8   \
# 0          Brand    Model               Variant    Series  Year  Kilometers
# 1         Toyota    Rukus               Build 2   AZE151R  2010      263000
# 2  Mercedes-Benz        V  250 D Avantgarde MWB  447 MY21  2021          19
# 3  Mercedes-Benz  Valente       116 CDI MWB RWD  447 MY21  2021          24
# 4  Mercedes-Benz     E250        CDI Avantgarde       207  2010      120579
#
#           9          10               11             12    13     14  \
# ...

# %% [markdown]
# Read data in the bottom.

# %%
df2 = df.tail()
df2.head()
# Out:
#              ID                                   Name  Price    Brand  \
# 17043  12852453     2003 Holden Commodore Executive VY   4499   Holden
# 17044  12852460            2008 Toyota Yaris YR NCP90R   4999   Toyota
# 17045  12852462   2002 Holden Jackaroo SE LWB (4X4) U8   7999   Holden
# 17046  12852463   2016 Hyundai I30 Active GD4 Series 2  14000  Hyundai
# 17047  12852464  2005 Toyota RAV4 Cruiser (4X4) ACA23R   5999   Toyota
#
#            Model        Variant        Series  Year  Kilometers       Type  \
# 17043  Commodore      Executive            VY  2003      230441      Sedan
# 17044      Yaris             YR        NCP90R  2008      237113  Hatchback
# 17045   Jackaroo   SE LWB (4X4)            U8  2002      238768      Wagon
# 17046        I30         Active  GD4 Series 2  2016       49800  Hatchback
# 17047       RAV4  Cruiser (4X4)        ACA23R  2005      255809      Wagon
#
#          Gearbox             Fuel Status    CC   Color  Seating Capacity
# ...

# %% [markdown]
# Change the column names of the data frame

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Price', 'Brand', 'Model', 'Variant', 'Series', 'Year',
#        'Kilometers', 'Type', 'Gearbox', 'Fuel', 'Status', 'CC', 'Color',
#        'Seating Capacity'],
#       dtype='object')

# %%
df.columns = ['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
       'Acceleration', 'Model', 'Origin', 'Car Name', 'Year', 'Price', 'Type', 'DriveTrain', 'name', 'mode']

# %%
df.head()
# Out:
#         Car                                                MPG  Cylinders  \
# 0  11530130                  2010 Toyota Rukus Build 2 AZE151R       9999
# 1  12190570  2021 Mercedes-Benz V 250 D Avantgarde MWB 447 ...     117990
# 2  12321855  2021 Mercedes-Benz Valente 116 CDI MWB RWD 447...      79990
# 3  12346971         2010 Mercedes-Benz E250 CDI Avantgarde 207      34990
# 4  12363884                       2016 Holden Cruze CD JH MY16      15990
#
#     Displacement Horsepower                Weight Acceleration  Model  Origin  \
# 0         Toyota      Rukus               Build 2      AZE151R   2010  263000
# 1  Mercedes-Benz          V  250 D Avantgarde MWB     447 MY21   2021      19
# 2  Mercedes-Benz    Valente       116 CDI MWB RWD     447 MY21   2021      24
# 3  Mercedes-Benz       E250        CDI Avantgarde          207   2010  120579
# 4         Holden      Cruze                    CD      JH MY16   2016   72506
#
# ...

# %%
url = '/content/drive/My Drive/Data_for_ML/cars_info.csv'
df_new = pd.read_csv(url)
df_new.head(1)
# Out:
#          ID                               Name  Price   Brand  Model  Variant  \
# 0  11530130  2010 Toyota Rukus Build 2 AZE151R   9999  Toyota  Rukus  Build 2
#
#     Series  Year  Kilometers   Type    Gearbox             Fuel Status    CC  \
# 0  AZE151R  2010      263000  Wagon  Automatic  Unleaded Petrol   Used  2362
#
#   Color  Seating Capacity
# 0  Grey                 5

# %% [markdown]
# Save the file in a specific path

# %%
path = '/content/drive/My Drive/Data_for_ML/cars_info_new.csv'
df_new.to_csv(path)

# %%
df.to_csv("automobile.csv", index=False)
# Here use index = False when index is not need

# %% [markdown]
# It is very important to check whether all data are in correct form. If there is any mismatch data in data frame we can identify that error using this method

# %%
df_new.dtypes
# Out:
# ID                   int64
# Name                object
# Price                int64
# Brand               object
# Model               object
# Variant             object
# Series              object
# Year                 int64
# Kilometers           int64
# Type                object
# Gearbox             object
# Fuel                object
# Status              object
# CC                   int64
# Color               object
# Seating Capacity     int64
# dtype: object

# %% [markdown]
# By using  describe function we can see the statistical summary.With the help of his summary we can see the deviations which may occur in datasets.

# %%
df_new.describe()
# Out:
#                  ID          Price          Year    Kilometers            CC  \
# count  1.704800e+04   17048.000000  17048.000000  1.704800e+04  17048.000000
# mean   1.279027e+07   36777.778038   2015.481288  1.032314e+05   2491.830303
# std    5.051111e+04   30305.015328      4.721591  8.041313e+04    881.985562
# min    1.153013e+07    1000.000000   1989.000000  1.000000e+00    875.000000
# 25%    1.275715e+07   18800.000000   2013.000000  4.450225e+04   1987.000000
# 50%    1.280207e+07   29990.000000   2016.000000  8.845400e+04   2354.000000
# 75%    1.283131e+07   45990.000000   2019.000000  1.488735e+05   2981.000000
# max    1.285246e+07  999000.000000   2022.000000  2.700000e+06   7300.000000
#
#        Seating Capacity
# count      17048.000000
# mean           5.115849
# std            1.121791
# min            2.000000
# 25%            5.000000
# 50%            5.000000
# 75%            5.000000
# max           14.000000

# %% [markdown]
# To get full data summary. we can use all method inside the describe.Here unique is the number of distinct objects in columns. Top is most frequently occuring object. Freq is number of time top object occur.We an see NaN becuase these columns contains non-Numerical values.

# %%
df_new.describe(include = 'all')
# Out:
#                   ID                                       Name  \
# count   1.704800e+04                                      17048
# unique           NaN                                       8575
# top              NaN  2018 Nissan X-Trail ST (2WD) T32 Series 2
# freq             NaN                                         33
# mean    1.279027e+07                                        NaN
# std     5.051111e+04                                        NaN
# min     1.153013e+07                                        NaN
# 25%     1.275715e+07                                        NaN
# 50%     1.280207e+07                                        NaN
# 75%     1.283131e+07                                        NaN
# max     1.285246e+07                                        NaN
#
#                 Price   Brand   Model Variant Series          Year  \
# count    17048.000000   17048   17048   17048  17048  17048.000000
# ...

# %% [markdown]
# we can use describe method to decribe selected data columns also.

# %%
df_new[['Variant','Price', 'Brand'] ].describe()
# Out:
#                Price
# count   17048.000000
# mean    36777.778038
# std     30305.015328
# min      1000.000000
# 25%     18800.000000
# 50%     29990.000000
# 75%     45990.000000
# max    999000.000000

# %% [markdown]
# Df.info is use for get concise summary.

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17048 entries, 0 to 17047
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                17048 non-null  int64
#  1   Name              17048 non-null  object
#  2   Price             17048 non-null  int64
#  3   Brand             17048 non-null  object
#  4   Model             17048 non-null  object
#  5   Variant           17048 non-null  object
#  6   Series            17048 non-null  object
#  7   Year              17048 non-null  int64
#  8   Kilometers        17048 non-null  int64
#  9   Type              17048 non-null  object
#  10  Gearbox           17048 non-null  object
#  11  Fuel              17048 non-null  object
#  12  Status            17048 non-null  object
#  13  CC                17048 non-null  int64
#  14  Color             17048 non-null  object
#  15  Seating Capacity  17048 non-null  int64
# ...

# %% [markdown]
# Writing a code using DB-API

# %%
#from dmodule import connect

# create connection object
#connection = connect('databasename','uername','pswd')

#create a curser object
#cursor = connection.cursor()

# Run queries
#cursor.execute('select * from mytable')
#result_type = cursor.fetchone()
#print(result_type)

#close connection
#connection.close()

# %% [markdown]
# Drop data when have null

# %%
# change the data as ? when there is null value
df1=df.replace('?',np.NaN)
# If use df.replace('?',np.nan ,inplace = True) This will make difference in exist data frame not make new data frame

# Drop rows contain null values in a specific column
df=df1.dropna(subset=["price"], axis=0)
# here using axis = 0 to drop entire row which contain null values in specific column
df.head(20)
